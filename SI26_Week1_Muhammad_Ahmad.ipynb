# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Ahmad-1263/urdu-ocr-codesaviours-si26-Muhammad-Ahmad/blob/main/SI26_Week1_Muhammad_Ahmad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install EasyOCR
# !pip install -q easyocr

# Import libraries
import easyocr
import pandas as pd
from google.colab import files

# Upload images
print("Select all the images you want to process.")
uploaded = files.upload()

# Initialize EasyOCR (Urdu + English)
reader = easyocr.Reader(['ur', 'en'])

# Extract text from each image
data = []

for image_name in uploaded.keys():
    print(f"Processing: {image_name}")

    try:
        result = reader.readtext(image_name, detail=0)
        extracted_text = " ".join(result).strip()

        data.append({
            "image": image_name,
            "label": extracted_text
        })

    except Exception as e:
        print(f"Error processing {image_name}: {e}")
        data.append({
            "image": image_name,
            "label": ""
        })

# Create DataFrame
df = pd.DataFrame(data)

# Save CSV
csv_file = "urdu_labels.csv"
df.to_csv(csv_file, index=False, encoding="utf-8-sig")

print("\nDone!")
print(df)

# Download CSV
files.download(csv_file)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 69.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 45.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.2/296.2 kB 20.5 MB/s eta 0:00:00
# Select all the images you want to process.
#      <input type="file" id="files-eec60edf-9c1e-4b53-ba55-4f29345f1272" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eec60edf-9c1e-4b53-ba55-4f29345f1272">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c9e0e4ec-fa52-4a4a-a739-026de4b245e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9e0e4ec-fa52-4a4a-a739-026de4b245e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir("."))
# Out:
# ['.config', 'Screenshot 2026-07-05 164807.png', 'Screenshot 2026-07-05 184154.png', 'Screenshot 2026-07-05 184015.png', 'Screenshot 2026-07-05 165430.png', 'Screenshot 2026-07-05 184027.png', 'Screenshot 2026-07-05 184140.png', 'Screenshot 2026-07-05 183941.png', 'Screenshot 2026-07-05 184009.png', 'Screenshot 2026-07-05 184113.png', 'Screenshot 2026-07-05 184250.png', 'Screenshot 2026-07-05 184049.png', 'Screenshot 2026-07-05 184044.png', 'Screenshot 2026-07-05 184118.png', 'Screenshot 2026-07-05 184003.png', 'Screenshot 2026-07-05 184241.png', 'Screenshot 2026-07-05 184107.png', 'Screenshot 2026-07-05 165348.png', 'Screenshot 2026-07-05 183951.png', 'Screenshot 2026-07-05 165415.png', 'Screenshot 2026-07-05 165337.png', 'Screenshot 2026-07-05 184031.png', 'Screenshot 2026-07-05 184057.png', 'Screenshot 2026-07-05 183909.png', 'Screenshot 2026-07-05 183902.png', 'Screenshot 2026-07-05 165324.png', 'urdu_ocr_week1_submission.zip', 'Screenshot 2026-07-05 164820.png', 'Screenshot 2026-
# ...

# %%
import zipfile

with zipfile.ZipFile("urdu_ocr_week1_submission.zip", "r") as zip_ref:
    zip_ref.extractall(".")

print("Extracted successfully.")
# Out:
# Extracted successfully.

# %%
folders = ['newspaper', 'books', 'signboards', 'synthetic', 'other']
for f in folders:
    path = f"data/raw/{f}"
    print(f"{f}: {len(os.listdir(path))} images")
# Out:
# newspaper: 57 images
# books: 20 images
# signboards: 20 images
# synthetic: 20 images
# other: 20 images

# %% [markdown]
# Week 1 – Part B: Research Task
# Question 1
# What is OCR (Optical Character Recognition)?
#
# Answer:
#
# Optical Character Recognition (OCR) is a technology that converts text from images or scanned documents into editable digital text. It allows computers to recognize printed or handwritten characters. OCR saves time by reducing manual typing and makes documents easier to edit and search.
#
# Question 2
# Why is Urdu OCR harder than English OCR?
#
# Answer:
#
# Urdu OCR is more difficult because Urdu letters are connected and change shape based on their position in a word. Small dots and marks are also important for identifying characters correctly. These features make Urdu text harder to recognize than English.
#
# Question 3
# What are two real-world situations where Urdu OCR would be useful?
#
# Answer:
#
# Urdu OCR can be used to convert old Urdu books and newspapers into digital text for easy storage and searching. It is also useful for digitizing printed forms and official documents in schools, banks, and government offices. This reduces manual work and improves efficiency.
